# %%
# ezen02-1
# 파이썬 기초 코딩
# 파이썬 기본 입출력
"""
  1. print(값)
     print(값1, 값2, ....)
      - end 속성
      - sep 속성
"""

data = "Hello Ezen!"
print(data)
# Out:
# Hello Ezen!

# %%
data1 = 7
data2 = 5
data3 = 8

print(data1, data2, data3)
print(data1, data2, data3, sep=", ")
print(data1, data2, data3, end="[END]")
print()
# Out:
# 7 5 8
# 7, 5, 8
# 7 5 8[END]

# %%
print('2022', '12', '07', sep='-')
print('niceyear', 'gmail.com', sep='@')
print()
# Out:
# 2022-12-07
# niceyear@gmail.com

# %%
# f-string을 사용하면 간단히 문자열을 출력 할 수 있음
score = 70
print(f"학생의 점수는 {score}점 입니다.")
# Out:
# 학생의 점수는 70점 입니다.

# %%
print("Test1: %5d, Price: %4.2f" %(776, 6534.123))
# Out:
# Test1:   776, Price: 6534.12

# %%
"""
  2. input()을 이용한 표준 입력
    1) input() : 키보드로부터 문자열을 입력받음
    2) int() : 사용자로부터 정수를 입력받음
"""

data = input()
print(data)
# Out:
# Hello man
# Hello man

# %%
name = input("당신의 이름은? ")
print("입력된 값 :", name)
# Out:
# 당신의 이름은? 김영채
# 입력된 값 : 김영채
