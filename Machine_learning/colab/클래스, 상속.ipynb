# %%
import sys

# %%
print(sys.stdout.encoding)
# Out:
# UTF-8

# %%
myName = "Ezen"

# 조건문
if myName == "Ezen":
  print("ok")

이름 = "이젠IT"
print(이름)
# Out:
# ok
# 이젠IT

# %%
# 상수 선언
def 인사():
  print("아듀 2022년, 해피뉴이어입니다.")

인사()
# Out:
# 아듀 2022년, 해피뉴이어입니다.

# %%
# 클래스
class Cookie:
  pass

# 객체 생성
cookie = Cookie()

# 객체 정보 값 출력
print(id(cookie))
# Out:
# 139703945855472
