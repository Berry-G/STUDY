# %% [markdown]
# # ML 프로젝트 수행 순서
# - 문제정의
# - 데이터 수집 및 정제
# - 탐색적 데이터 분석
# - 피처(독립변수) 엔지니어링
# - 예측 모델 개발 및 평가가

# %% [markdown]
# # ML Framework : Scikit-Learn
# - 파이썬 오픈소스 라이브러리 중에서 머신러닝을 구현하는데 특화된 라이브러리
# - sklearn은 거의 대부분의 머신러닝 알고리즘이 구현되어 있음
# - 굉장히 구조적으로 잘 만들어져 있어서 사용하기 편리함

# %% [markdown]
# # Classification (분류)
# - 주어진 데이터(x)를 분류하고자 하는 값(y)에 할당하는 방법
# - 비슷한 특징을 가지는 데이터가 같은 분류로 나뉘어지는 것은 서로 상대적으로 가까운 feature들이 같은 target value를 부여받는 것임.
# - 예를 들어, 고양이와 강아지 사진이 섞여있는 2000장의 이미지가 있다. 고양양이 사진을 머신러닝 모델이 판단해서 "Cat"이라고 Label을 부여함.
# - 여기서 라벨은 0 또는 1로 표기하는 것이 일반적임.
# - e.g. Cat(0), Dog(1)
# - 머신러닝 분류 모델을 거치면 binary classification이라고 함.
# - 머신러닝 분류 모델 종류 : Logistic Regression, Linear Classifier, KNN, Neural Network...

# %% [markdown]
# # Classification - Model : Logistic Regression
# - 주어진 데이터(x)를 통해서 사건의 발생 확률(y)를 예측하는 통계 모델
# - 대표적인 이진 분류 모델임
# - 전체 데이터의 경향성을 파악하는 선형식을 구하는 방법을 말함
# - y = b + b * x
# - 특정 값(target value)을 예측하는 것을 목표로 함.
# - 특정 값을 찾기 위해서는 주어진 데이터(training data)의 패턴을 찾아야 함.
# - 그 패턴을 선형식으로 파악하는 것이 Linear Regression 이라고 함.

# %% [markdown]
# # 타이타닉 생존자 예측 ML
# - 로지스틱 회귀 분석 모델을 사용(선형 분류)
# - 로지스틱 회귀 : 선형 회귀 분석을 기반으로 한 모델로, 연속성 종속변수가 아닌 이진분류 문제를 위한 알고리즘임.
# - ML1 : 선형 회귀 분석은 연속된 변수를 예측함
# - ML2 : Yes/No 처럼 두가지로 나뉘는 분류 문제를 예측함
# - 생존자를 예측, 작동 원리 이해
# - 분류(Classification) 문제 예측 및 평가가

# %% [markdown]
# # 진행순서
# - 문제 정의
# - 라이브러리 및 데이터 불러오기
# - 데이터 확인하기
# - 전처리(독립변수)
# - 모델링 및 예측

# %% [markdown]
# # 문제 정의
# - 예측 목표 : 타이타닉 승객 정보 데이터셋을 이용한 생존 여부를 예측
# - 종속 변수 : Survived (생존 여부)
# - 사용 모델 : Logistiic Regression
# - 유형 : 분류
# - 평가 : 정확도
